# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\Li\Desktop\LAD关键词.xlsx")
df
# Out:
#            贸易合作与投资      中国与东南亚合作共建          技术与产业      市场与金融服务         企业发展  \
# 0      development       singapore        network       market          bri
# 1      cooperation            year        company       growth      service
# 2          project            city       industry     business     employee
# 3            trade     development       research      payment      partner
# 4            world         country  communication        group       client
# 5           people      investment         system    indonesia     solution
# 6             year           trade        service      company      payment
# 7          economy             bri    corporation         loan         year
# 8             city      government         report      service      benefit
# 9             area    construction    application       impact     platform
# 10      investment        thailand         design        event          ceo
# ...

# %%
df['贸易合作与投资']
# Out:
# 0        development
# 1        cooperation
# 2            project
# 3              trade
# 4              world
# 5             people
# 6               year
# 7            economy
# 8               city
# 9               area
# 10        investment
# 11        government
# 12          industry
# 13           company
# 14          victoria
# 15      construction
# 16            market
# 17          business
# 18         community
# 19            growth
# 20    infrastructure
# Name: 贸易合作与投资, dtype: object

# %%
list=[]
list2=[]
list3=[]
for i in df['贸易合作与投资']:
    list.append(i)
    
for i in df['中国与东南亚合作共建']:
    list2.append(i)

for i in df['技术与产业']:
    list3.append(i)
list4=[]
for i in df['市场与金融服务']:
    list4.append(i)
    
list5=[]
for i in df['企业发展']:
    list5.append(i)

list6=[]
for i in df['新冠疫情']:
    list6.append(i)
    
list7=[]
for i in df['中国与南亚合作共建']:
    list7.append(i)

list8=[]
for i in df['外交关系与国际竞争']:
    list8.append(i)
list9=[]
for i in df['军备实力']:
    list9.append(i)
    
list10=[]
for i in df['中国与东南亚合作共建']:
    list10.append(i)
list11=[]
for i in df['国家主权与安全']:
    list11.append(i)

# %%
list12=[]
for i in df['人权保障与发展']:
    list12.append(i)

# %%
dict={}
dict['贸易合作与投资']=list
dict['中国与东南亚合作共建']=list2
dict['技术与产业']=list3
dict['市场与金融服务']=list4
dict['企业发展']=list5
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-b52f02af09af> in <module>
#       5 dict['市场与金融服务']=list4
#       6 dict['企业发展']=list5
# ----> 7 dict[4]
#
# KeyError: 4

# %%
dict['新冠疫情']=list6

# %%
dict['中国与南亚合作共建']=list7

# %%
dict['外交关系与国际竞争']=list8

# %%
dict['军备实力']=list9

# %%
dict['中国与东南亚合作共建']=list10

# %%
dict['国家主权与安全']=list11

# %%
dict['人权保障与发展']=list12

# %%
dict
# Out:
# {'贸易合作与投资': ['development',
#   'cooperation',
#   'project',
#   'trade',
#   'world',
#   'people',
#   'year',
#   'economy',
#   'city',
#   'area',
#   'investment',
#   'government',
#   'industry',
#   'company',
#   'victoria',
#   'construction',
#   'market',
#   'business',
#   'community',
#   'growth',
#   'infrastructure'],
#  '中国与东南亚合作共建': ['singapore',
#   'year',
#   'city',
#   'development',
#   'country',
#   'investment',
#   'trade',
#   'bri',
#   'government',
#   'construction',
#   'thailand',
#   'infrastructure',
#   'cooperation',
#   'railway',
#   'visit',
#   'mr',
#   'area',
#   'zone',
#   'laos',
#   'capital',
#   'company'],
#  '技术与产业': ['network',
#   'company',
#   'industry',
#   'research',
#   'communication',
#   'system',
#   'service',
#   'corporation',
#   'report',
#   'application',
#   'design',
#   'solution',
#   'product',
#   'association',
#   'group',
#   'association',
#   'analysis',
#   'growth',
#   'logistic',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-674420c0f9cc> in <module>
# ----> 1 dict[4]
#
# KeyError: 4
