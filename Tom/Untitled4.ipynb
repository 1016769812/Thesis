# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel(r"C:\Users\Li\Desktop\LDA.xlsx",index_col="序号")
keywords=data["关键词"]
theme=data["主题"]
data[theme=='新冠疫情'].index.tolist()[0]
# Out:
# 5

# %%
values=[]
for i in keywords:
    list1=i.split(',')
    values.append(list1)
   
keys=[i for i in theme]
keys
# Out:
# ['贸易合作与投资',
#  '外交关系与国家竞争',
#  '市场与金融服务',
#  '科技与产业',
#  '新冠疫情',
#  '南亚合作与交流',
#  '地区人权与和平',
#  '项目工程建设',
#  '文化交流与外贸',
#  '东南亚合作与交流',
#  '国家主权与安全',
#  '违规争议性事件']

# %%
len(values)
# Out:
# 12

# %%
#a = [dict(zip(keys,values)) for row in values] if values else None
dic={}
for i in range(0,13):
    print(values[i])
# Out:
# ['BRI', ' country', ' cooperation', ' development', ' singapore', ' trade', ' world', ' economy', ' area', ' investment', ' people', ' initiative', ' government', ' city', ' market，africa', ' iran', ' crisis', ' continent', ' respondent', ' policy', ' deficit', 'soybean', 'party，russia', ' europe', ' wine', ' oil', ' australia', ' moscow', ' bottle', ' beef', ' import', ' market', ' wildlife', ' karamay', ' petrochemical', '']
# ['country', ' relation', ' interest', ' relationship', ' influence', ' japan', ' per_cent', ' cambodia', 'cyberspace', 'competition', 'switzerland', 'sport', ' guangxi', ' weaponisation', ' governance', 'security，investment', ' government', ' mr', ' trade', ' security', ' world', ' state', ' beijing', ' australia', ' BRI', ' time', ' policy', ' power', ' ']
# ...

# %%
for i in range(0,13):
    print(keys[i])
# Out:
# 贸易合作与投资
# 外交关系与国家竞争
# 市场与金融服务
# 科技与产业
# 新冠疫情
# 南亚合作与交流
# 地区人权与和平
# 项目工程建设
# 文化交流与外贸
# 东南亚合作与交流
# 国家主权与安全
# 违规争议性事件
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-71-fcd6818c1205> in <module>
#       1 for i in range(0,13):
# ----> 2     print(keys[i])
#
# IndexError: list index out of range

# %%
keys_attributeslist={
                    '贸易合作与投资':['BRI', ' country', ' cooperation'],
                     '外交关系与国家竞争':['country', ' relation', ' interest'],
                     '市场与金融服务':['business', ' company', ' bank'],
                     '科技与产业':['technology', ' market', ' network'],
                     '新冠疫情':['country', ' BRI', ' coronavirus'],
                     '南亚合作与交流':['india', ' country', ' region'],
                     '地区人权与和平':['world', ' people', ' africa'],
                     '项目工程建设':['project', ' construction', ' energy'],
                     '文化交流与外贸':['trade', ' BRI', ' exhibition'],
               '东南亚合作与交流':['myanmar', 'visit', ' project'],
                    '国家主权与安全':['indoesia', ' mr', ' sovereugnty'],
                     '违规争议性事件':['america', ' pipeline', 'myanmar']
                    }

# %%
df=pd.DataFrame(keys_attributeslist)
df
# Out:
#         贸易合作与投资  外交关系与国家竞争   市场与金融服务       科技与产业          新冠疫情   南亚合作与交流  \
# 0           BRI    country  business  technology       country     india
# 1       country   relation   company      market           BRI   country
# 2   cooperation   interest      bank     network   coronavirus    region
#
#    地区人权与和平         项目工程建设      文化交流与外贸  东南亚合作与交流       国家主权与安全    违规争议性事件
# 0    world        project        trade   myanmar      indoesia    america
# 1   people   construction          BRI     visit            mr   pipeline
# 2   africa         energy   exhibition   project   sovereugnty    myanmar

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-ad11118bc8f3> in <module>
# ----> 1 df[0]
#
# ...

# %%
with open(r"C:\Users\Li\Desktop\新加坡（txt）\Singa.txt",'r',encoding='utf-8') as f:
   data=f.read()
   formated_data=data.split(' ')

# %%
formated_data
# Out:
# ['',
#  '\n\n\nStraits',
#  'Times',
#  'Breaking',
#  'News\nSouth',
#  'Asia\nPolitical',
#  'crisis',
#  'in',
#  'Nepal',
#  'could',
#  'shake',
#  'up',
#  'its',
#  'ties',
#  'with',
#  'India',
#  'and',
#  'China\n\nNirmala',
#  'Ganapathy',
#  '\n919',
#  'words\n31',
#  'December',
#  '2020\nThe',
#  'Straits',
#  'Times\nSTIMES\nEnglish\n(c)',
#  '2020',
#  'Singapore',
#  'Press',
#  'Holdings',
#  'Limited',
#  '\n\nNEW',
#  'DELHI',
#  '-',
#  'An',
#  'unfolding',
#  'political',
#  'crisis',
#  'in',
#  'Nepal',
#  'is',
#  'not',
#  'only',
#  'shaking',
#  'up',
#  'the',
#  'nation,',
#  'but',
#  'could',
#  'also',
#  'fuel',
#  'a',
#  'reshaping',
#  'of',
#  'its',
#  'relations',
#  'with',
#  'its',
#  'two',
#  'giant',
#  'neighbours',
#  '-',
#  'India',
#  'and',
#  "China.\n\nNepal's",
#  'Prime',
#  'Minister,',
#  'Mr',
#  'K.P.',
#  'Sharma',
#  'Oli,',
#  'fearing',
#  'a',
#  'no-confidence',
#  'motion,',
#  'has',
#  'recommended',
#  'the',
# ...

# %%
dict={'theme':['india', ' country', ' region']}
data=('india ni hao country china region region fuck you east i am bored')
dict['theme']
# Out:
# ['india', ' country', ' region']

# %%
for i in list:
    if i in dict['theme']:
        print(i)
# Out:
# india
#  country
#  region
